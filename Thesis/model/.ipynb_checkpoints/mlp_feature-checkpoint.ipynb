# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn2pmml import sklearn2pmml, PMMLPipeline

# %%
data = pd.read_csv('two_category.csv')
data = pd.get_dummies(data, columns=['classic_bluetooth'], prefix='classic_bluetooth')
X = np.stack(data[['packet_len', 'ad_cnt', 'classic_bluetooth_unknown', 'classic_bluetooth_yes', 'classic_bluetooth_no']].values)

# One-Hot Encoding for device types
encoder = OneHotEncoder(sparse=False)
device_type_onehot = encoder.fit_transform(data[['label']])

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, device_type_onehot, test_size=0.2, random_state=41)


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define a Multi-layer Perceptron classifier
mlp = MLPClassifier(max_iter=1000, random_state=42)

# Define hyperparameters for grid search
parameter_space = {
    'hidden_layer_sizes': [(10, 5),(10,),(20,), (50,) ,(10,10), (10,20), (10,50),(10,10,10), (10,20,10), (10,40,10), (20,20,20), (20,50,20),(50,50,50)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant','adaptive'],
    'learning_rate_init': [0.1, 0.01, 0.001, 0.0001]
}

# Grid search with cross-validation
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)

# Print out the best parameters
print('Best parameters found:\n', clf.best_params_)

# Predict using the model with the best parameters
y_pred = clf.predict(X_test)

# Test the model
score = clf.score(X_test, y_test)
print("Test score: ", score)

# %%
# One-Hot Encoding for device types
encoder = OneHotEncoder(sparse=False)
device_type_onehot = encoder.fit_transform(data[['label']])

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, device_type_onehot, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define a Multi-layer Perceptron classifier
mlp = MLPClassifier(hidden_layer_sizes=(10, 40, 10), max_iter=2000, alpha=0.0001,
                    solver='sgd', verbose=10, random_state=42,
                    learning_rate_init=0.1, activation = 'relu')


# Train the model
mlp.fit(X_train, y_train)

# Test the model
score = mlp.score(X_test, y_test)
print("Test score: ", score)

# %%
y_test_pred = mlp.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_test_pred))

cm = confusion_matrix(y_test.argmax(axis=1), y_test_pred.argmax(axis=1))

# %%
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(10,7))
class_names = ['non-tracker', 'tracker']
sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.yticks(rotation=0) 
plt.show()

# %%
unseen_data = pd.read_csv('two_category_unseen.csv')
X_unseen = np.stack(unseen_data[['packet_len', 'ad_cnt', 'bluetooth_unknown',  'bluetooth_yes', 'bluetooth_no']].values)
device_type_onehot = encoder.transform(unseen_data[['label']])
X_unseen = scaler.transform(X_unseen)
y_unseen = device_type_onehot
# Unseen devices test
score = mlp.score(X_unseen, y_unseen)
y_pred = mlp.predict(X_unseen)
print(score)
print(classification_report(y_unseen, y_pred))
cm = confusion_matrix(y_unseen.argmax(axis=1), y_pred.argmax(axis=1))

# %%
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(10,7))
class_names = ['non-tracker', 'tracker']
sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.yticks(rotation=0) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data[data['label'] == 'tracker'], x='packet_len', label='tracker', fill=True)
sns.kdeplot(data=data[data['label'] == 'non_tracker'], x='packet_len', label='non-tracker', fill=True)

plt.title('Probability Density of Packet Length for Tracker vs Non-Tracker')
plt.xlabel('Packet Length')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data[data['label'] == 'tracker'], x='ad_cnt', label='tracker', fill=True)
sns.kdeplot(data=data[data['label'] == 'non_tracker'], x='ad_cnt', label='non-tracker', fill=True)

plt.title('Probability Density of Number of AD for Tracker vs Non-Tracker')
plt.xlabel('Packet Length')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
data = pd.read_csv('two_category.csv')

tracker_counts = data[data['label'] == 'tracker']['classic_bluetooth'].value_counts(normalize=True) * 100
non_tracker_counts = data[data['label'] == 'non_tracker']['classic_bluetooth'].value_counts(normalize=True) * 100

combined_data = pd.concat([tracker_counts, non_tracker_counts], axis=1)
combined_data.columns = ['tracker', 'non-tracker']

ax = combined_data.plot(kind='bar', figsize=(12, 6))
ax.set_ylabel('Percentage')
ax.set_title('Distribution of classic bluetooth supported feature')
plt.xticks(rotation=0)  # 设置x轴标签的角度
plt.show()

# %%
data = pd.read_csv('two_category.csv')


tracker_counts = data[data['label'] == 'tracker']['manufacturer_or_service'].value_counts(normalize=True) * 100
non_tracker_counts = data[data['label'] == 'non_tracker']['manufacturer_or_service'].value_counts(normalize=True) * 100


combined_data = pd.concat([tracker_counts, non_tracker_counts], axis=1)
combined_data.columns = ['Tracker', 'Non-Tracker']


ax = combined_data.plot(kind='bar', figsize=(12, 6))
ax.set_ylabel('Percentage')
ax.set_title('Distribution of manufacturer_or_service states')
plt.xticks(rotation=0)  # 设置x轴标签的角度
plt.show()

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import plot_model

# L2 regularization
regularizer = l2(1e-4)

data = pd.read_csv('two_category.csv')
data = pd.get_dummies(data, columns=['classic_bluetooth'], prefix='classic_bluetooth')
X = np.stack(data[['packet_len', 'ad_cnt', 'classic_bluetooth_unknown', 'classic_bluetooth_yes', 'classic_bluetooth_no']].values)

# Split data first
X_train, X_test, y_train_raw, y_test_raw = train_test_split(X, data['label'], test_size=0.2, random_state=42)

# Label Encoding for device types
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(y_train_raw)
y_test_encoded = encoder.transform(y_test_raw)

# Convert labels to categorical
y_train_categorical = to_categorical(y_train_encoded)
y_test_categorical = to_categorical(y_test_encoded)

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define the model
model = Sequential()
model.add(Dense(10, activation='relu', kernel_regularizer=regularizer, input_shape=(X_train.shape[1],)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(20, activation='relu', kernel_regularizer=regularizer))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(10, activation='relu', kernel_regularizer=regularizer))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(y_train_categorical.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(X_train, y_train_categorical, epochs=2000, verbose=1)

# Predict using the model (though not used later in your code)
y_predict = model.predict(X_test)

# Test the model
score = model.evaluate(X_test, y_test_categorical, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])

# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with tf.io.gfile.GFile('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Epoch 1/2000
# 30/30 [==============================] - 1s 2ms/step - loss: 0.6966 - accuracy: 0.7216
# Epoch 2/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4822 - accuracy: 0.8078
# Epoch 3/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.8456
# Epoch 4/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4182 - accuracy: 0.8487
# Epoch 5/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8466
# Epoch 6/2000
# 30/30 [==============================] - 0s 1ms/step - loss: 0.3916 - accuracy: 0.8603
# Epoch 7/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8750
# Epoch 8/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8739
# Epoch 9/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.8750
# Epoch 10/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8687
# Epoch 11/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8845
# Epoch 12/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3510 - accuracy: 0.8739
# Epoch 13/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8824
# Epoch 14/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8834
# Epoch 15/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.8803
# Epoch 16/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8876
# Epoch 17/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3350 - accuracy: 0.8897
# Epoch 18/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8771
# Epoch 19/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3085 - accuracy: 0.8887
# Epoch 20/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8750
# Epoch 21/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3172 - accuracy: 0.8897
# Epoch 22/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.9013
# Epoch 23/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8813
# Epoch 24/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.8834
# Epoch 25/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3094 - accuracy: 0.8918
# Epoch 26/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3235 - accuracy: 0.8855
# Epoch 27/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3130 - accuracy: 0.8897
# Epoch 28/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2947 - accuracy: 0.8971
# Epoch 29/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3221 - accuracy: 0.8866
# Epoch 30/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.9044
# Epoch 31/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8792
# Epoch 32/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2933 - accuracy: 0.8887
# Epoch 33/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.8981
# Epoch 34/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2924 - accuracy: 0.8992
# Epoch 35/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.8960
# Epoch 36/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3169 - accuracy: 0.8813
# Epoch 37/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2831 - accuracy: 0.9013
# Epoch 38/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3016 - accuracy: 0.9013
# Epoch 39/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.8897
# Epoch 40/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3002 - accuracy: 0.8876
# Epoch 41/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.8887
# Epoch 42/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.8971
# Epoch 43/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.8971
# Epoch 44/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.8908
# Epoch 45/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3077 - accuracy: 0.8960
# Epoch 46/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3052 - accuracy: 0.8824
# Epoch 47/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3129 - accuracy: 0.8950
# Epoch 48/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3024 - accuracy: 0.8981
# Epoch 49/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.8866
# Epoch 50/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2920 - accuracy: 0.9076
# Epoch 51/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2842 - accuracy: 0.9023
# Epoch 52/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2673 - accuracy: 0.9118
# Epoch 53/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 0.8887
# Epoch 54/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.8992
# Epoch 55/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8939
# Epoch 56/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2912 - accuracy: 0.9013
# Epoch 57/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.8845
# Epoch 58/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2827 - accuracy: 0.9013
# Epoch 59/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2968 - accuracy: 0.8929
# Epoch 60/2000
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2840 - accuracy: 0.9023
# Epoch 61/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.9065
# Epoch 62/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2820 - accuracy: 0.9002
# Epoch 63/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2860 - accuracy: 0.8981
# Epoch 64/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2836 - accuracy: 0.9013
# Epoch 65/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.9002
# Epoch 66/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.9055
# Epoch 67/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2673 - accuracy: 0.9065
# Epoch 68/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3296 - accuracy: 0.8866
# Epoch 69/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2861 - accuracy: 0.9023
# Epoch 70/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2852 - accuracy: 0.9002
# Epoch 71/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.9034
# Epoch 72/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2958 - accuracy: 0.8908
# Epoch 73/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2946 - accuracy: 0.8939
# Epoch 74/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.8992
# Epoch 75/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.9034
# Epoch 76/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2846 - accuracy: 0.9023
# Epoch 77/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.8939
# Epoch 78/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2790 - accuracy: 0.9034
# Epoch 79/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.9013
# Epoch 80/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.9076
# Epoch 81/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.9002
# Epoch 82/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2815 - accuracy: 0.8929
# Epoch 83/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2664 - accuracy: 0.9013
# Epoch 84/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2846 - accuracy: 0.9002
# Epoch 85/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.9044
# Epoch 86/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.9034
# Epoch 87/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.9107
# Epoch 88/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.9034
# Epoch 89/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2834 - accuracy: 0.8981
# Epoch 90/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2871 - accuracy: 0.9002
# Epoch 91/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.9013
# Epoch 92/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2886 - accuracy: 0.8992
# Epoch 93/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2854 - accuracy: 0.9055
# Epoch 94/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8960
# Epoch 95/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2846 - accuracy: 0.9034
# Epoch 96/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.9034
# Epoch 97/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2753 - accuracy: 0.8971
# Epoch 98/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2824 - accuracy: 0.9002
# Epoch 99/2000
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2661 - accuracy: 0.9107
# Epoch 100/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.8992
# Epoch 101/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.9076
# Epoch 102/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2803 - accuracy: 0.9013
# Epoch 103/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2926 - accuracy: 0.9002
# Epoch 104/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.9013
# Epoch 105/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.9128
# Epoch 106/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.9023
# Epoch 107/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2726 - accuracy: 0.8960
# Epoch 108/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.9097
# Epoch 109/2000
# 30/30 [==============================] - 0s 1ms/step - loss: 0.2699 - accuracy: 0.9023
# Epoch 110/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.9034
# Epoch 111/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.9044
# Epoch 112/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2829 - accuracy: 0.9023
# Epoch 113/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9107
# Epoch 114/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.8929
# Epoch 115/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.9097
# Epoch 116/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.9034
# Epoch 117/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.8971
# Epoch 118/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2675 - accuracy: 0.9055
# Epoch 119/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2653 - accuracy: 0.9044
# Epoch 120/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2743 - accuracy: 0.8981
# Epoch 121/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.9023
# Epoch 122/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9065
# Epoch 123/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2778 - accuracy: 0.8939
# Epoch 124/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9044
# Epoch 125/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2657 - accuracy: 0.9086
# Epoch 126/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2587 - accuracy: 0.9044
# Epoch 127/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.8992
# Epoch 128/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9139
# Epoch 129/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.9055
# Epoch 130/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.9076
# Epoch 131/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2835 - accuracy: 0.9002
# Epoch 132/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2672 - accuracy: 0.9097
# Epoch 133/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9065
# Epoch 134/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2581 - accuracy: 0.9097
# Epoch 135/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.9055
# Epoch 136/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.8981
# Epoch 137/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8992
# Epoch 138/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.9055
# Epoch 139/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.8971
# Epoch 140/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.8971
# Epoch 141/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.9044
# Epoch 142/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.9107
# Epoch 143/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.9065
# Epoch 144/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2622 - accuracy: 0.9076
# Epoch 145/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.9065
# Epoch 146/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.9023
# Epoch 147/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.9097
# Epoch 148/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.9086
# Epoch 149/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.9055
# Epoch 150/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2846 - accuracy: 0.9013
# Epoch 151/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2778 - accuracy: 0.9055
# Epoch 152/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.9076
# Epoch 153/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.8960
# Epoch 154/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.9023
# Epoch 155/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.9055
# Epoch 156/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.9086
# Epoch 157/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2716 - accuracy: 0.8929
# Epoch 158/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.9023
# Epoch 159/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.9002
# Epoch 160/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9002
# Epoch 161/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2592 - accuracy: 0.9107
# Epoch 162/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2592 - accuracy: 0.9055
# Epoch 163/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.9097
# Epoch 164/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2737 - accuracy: 0.8981
# Epoch 165/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.9107
# Epoch 166/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9139
# Epoch 167/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.9023
# Epoch 168/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2728 - accuracy: 0.9097
# Epoch 169/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9128
# Epoch 170/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.9086
# Epoch 171/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.9055
# Epoch 172/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2698 - accuracy: 0.9055
# Epoch 173/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2729 - accuracy: 0.9065
# Epoch 174/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.9023
# Epoch 175/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2573 - accuracy: 0.9065
# Epoch 176/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.9065
# Epoch 177/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2734 - accuracy: 0.9013
# Epoch 178/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9023
# Epoch 179/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.8939
# Epoch 180/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.9107
# Epoch 181/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.9013
# Epoch 182/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2664 - accuracy: 0.9044
# Epoch 183/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.9118
# Epoch 184/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.9044
# Epoch 185/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2553 - accuracy: 0.9086
# Epoch 186/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.9065
# Epoch 187/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2550 - accuracy: 0.9013
# Epoch 188/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.9044
# Epoch 189/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.9086
# Epoch 190/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.9076
# Epoch 191/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9107
# Epoch 192/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.9034
# Epoch 193/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9149
# Epoch 194/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.9044
# Epoch 195/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2672 - accuracy: 0.8971
# Epoch 196/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2817 - accuracy: 0.9013
# Epoch 197/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9086
# Epoch 198/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9139
# Epoch 199/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2613 - accuracy: 0.9076
# Epoch 200/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.9107
# Epoch 201/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.9013
# Epoch 202/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2614 - accuracy: 0.8960
# Epoch 203/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.8950
# Epoch 204/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.9034
# Epoch 205/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.9034
# Epoch 206/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2596 - accuracy: 0.9013
# Epoch 207/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2681 - accuracy: 0.8981
# Epoch 208/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8992
# Epoch 209/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9097
# Epoch 210/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.8971
# Epoch 211/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2783 - accuracy: 0.9044
# Epoch 212/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2454 - accuracy: 0.9118
# Epoch 213/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2729 - accuracy: 0.8939
# Epoch 214/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2651 - accuracy: 0.9086
# Epoch 215/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9097
# Epoch 216/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8981
# Epoch 217/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2776 - accuracy: 0.8971
# Epoch 218/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2626 - accuracy: 0.9076
# Epoch 219/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2630 - accuracy: 0.9076
# Epoch 220/2000
# 30/30 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.91 - 0s 2ms/step - loss: 0.2534 - accuracy: 0.9181
# Epoch 221/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.9065
# Epoch 222/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.9034
# Epoch 223/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.9013
# Epoch 224/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.9044
# Epoch 225/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.9139
# Epoch 226/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.9118
# Epoch 227/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.9139
# Epoch 228/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.9097
# Epoch 229/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2794 - accuracy: 0.9023
# Epoch 230/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.9044
# Epoch 231/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2690 - accuracy: 0.9065
# Epoch 232/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9065
# Epoch 233/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.9086
# Epoch 234/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.9128
# Epoch 235/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2731 - accuracy: 0.9065
# Epoch 236/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2715 - accuracy: 0.9013
# Epoch 237/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.9055
# Epoch 238/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.8992
# Epoch 239/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.9065
# Epoch 240/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.9076
# Epoch 241/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2654 - accuracy: 0.9076
# Epoch 242/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9002
# Epoch 243/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9055
# Epoch 244/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.9013
# Epoch 245/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.9181
# Epoch 246/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2538 - accuracy: 0.9118
# Epoch 247/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.9044
# Epoch 248/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.9013
# Epoch 249/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.9097
# Epoch 250/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.9139
# Epoch 251/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2694 - accuracy: 0.8960
# Epoch 252/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2837 - accuracy: 0.9076
# Epoch 253/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9128
# Epoch 254/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2632 - accuracy: 0.9055
# Epoch 255/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9086
# Epoch 256/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.9149
# Epoch 257/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.9065
# Epoch 258/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9076
# Epoch 259/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.9034
# Epoch 260/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.9139
# Epoch 261/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.9139
# Epoch 262/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.9013
# Epoch 263/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2588 - accuracy: 0.9034
# Epoch 264/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9149
# Epoch 265/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9076
# Epoch 266/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.9097
# Epoch 267/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9160
# Epoch 268/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2655 - accuracy: 0.9013
# Epoch 269/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.9107
# Epoch 270/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.8992
# Epoch 271/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2857 - accuracy: 0.8981
# Epoch 272/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.9118
# Epoch 273/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2465 - accuracy: 0.9149
# Epoch 274/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.9044
# Epoch 275/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2716 - accuracy: 0.9097
# Epoch 276/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.9002
# Epoch 277/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2386 - accuracy: 0.9139
# Epoch 278/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.9002
# Epoch 279/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.9013
# Epoch 280/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2391 - accuracy: 0.9139
# Epoch 281/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2592 - accuracy: 0.9097
# Epoch 282/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.9097
# Epoch 283/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2725 - accuracy: 0.9076
# Epoch 284/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9034
# Epoch 285/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.9097
# Epoch 286/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2680 - accuracy: 0.9065
# Epoch 287/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.9065
# Epoch 288/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.9076
# Epoch 289/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.9044
# Epoch 290/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.8950
# Epoch 291/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2586 - accuracy: 0.9034
# Epoch 292/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2588 - accuracy: 0.9013
# Epoch 293/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9128
# Epoch 294/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9181
# Epoch 295/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2386 - accuracy: 0.9107
# Epoch 296/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9086
# Epoch 297/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.9097
# Epoch 298/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.9055
# Epoch 299/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2737 - accuracy: 0.9002
# Epoch 300/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.9076
# Epoch 301/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2481 - accuracy: 0.9023
# Epoch 302/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.9002
# Epoch 303/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2702 - accuracy: 0.9086
# Epoch 304/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.9044
# Epoch 305/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.9055
# Epoch 306/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.9086
# Epoch 307/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.9118
# Epoch 308/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2790 - accuracy: 0.8981
# Epoch 309/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.9160
# Epoch 310/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.9160
# Epoch 311/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.9181
# Epoch 312/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.9118
# Epoch 313/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.9118
# Epoch 314/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9034
# Epoch 315/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.9086
# Epoch 316/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.9065
# Epoch 317/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.9149
# Epoch 318/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2410 - accuracy: 0.9139
# Epoch 319/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2450 - accuracy: 0.9149
# Epoch 320/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9055
# Epoch 321/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8981
# Epoch 322/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.9139
# Epoch 323/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9086
# Epoch 324/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9128
# Epoch 325/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2553 - accuracy: 0.9086
# Epoch 326/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2653 - accuracy: 0.9065
# Epoch 327/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2586 - accuracy: 0.9044
# Epoch 328/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.9118
# Epoch 329/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.9076
# Epoch 330/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.9118
# Epoch 331/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.9097
# Epoch 332/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2558 - accuracy: 0.9044
# Epoch 333/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2722 - accuracy: 0.9034
# Epoch 334/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9065
# Epoch 335/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2516 - accuracy: 0.9149
# Epoch 336/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.9107
# Epoch 337/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.9097
# Epoch 338/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.9139
# Epoch 339/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.9034
# Epoch 340/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2704 - accuracy: 0.9013
# Epoch 341/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9191
# Epoch 342/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.9023
# Epoch 343/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.9034
# Epoch 344/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.9160
# Epoch 345/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9034
# Epoch 346/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9107
# Epoch 347/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2514 - accuracy: 0.9139
# Epoch 348/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.9139
# Epoch 349/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2553 - accuracy: 0.9065
# Epoch 350/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9128
# Epoch 351/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9065
# Epoch 352/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2588 - accuracy: 0.9097
# Epoch 353/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.9076
# Epoch 354/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.9128
# Epoch 355/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.8971
# Epoch 356/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.9097
# Epoch 357/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.9170
# Epoch 358/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2662 - accuracy: 0.8992
# Epoch 359/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2572 - accuracy: 0.9097
# Epoch 360/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.9139
# Epoch 361/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.9139
# Epoch 362/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2622 - accuracy: 0.9034
# Epoch 363/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.9044
# Epoch 364/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.9065
# Epoch 365/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.9139
# Epoch 366/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9023
# Epoch 367/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2576 - accuracy: 0.9097
# Epoch 368/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9128
# Epoch 369/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2556 - accuracy: 0.9181
# Epoch 370/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9160
# Epoch 371/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2675 - accuracy: 0.9002
# Epoch 372/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9170
# Epoch 373/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.9086
# Epoch 374/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.9097
# Epoch 375/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2588 - accuracy: 0.9097
# Epoch 376/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.9044
# Epoch 377/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.9107
# Epoch 378/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.9107
# Epoch 379/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2561 - accuracy: 0.9107
# Epoch 380/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.9013
# Epoch 381/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.9202
# Epoch 382/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9097
# Epoch 383/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.9055
# Epoch 384/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2550 - accuracy: 0.9044
# Epoch 385/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.9023
# Epoch 386/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9107
# Epoch 387/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2599 - accuracy: 0.9044
# Epoch 388/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2400 - accuracy: 0.9128
# Epoch 389/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9076
# Epoch 390/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2576 - accuracy: 0.9076
# Epoch 391/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9149
# Epoch 392/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.9149
# Epoch 393/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2410 - accuracy: 0.9055
# Epoch 394/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.9076
# Epoch 395/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2561 - accuracy: 0.9055
# Epoch 396/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.9107
# Epoch 397/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9139
# Epoch 398/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2470 - accuracy: 0.9107
# Epoch 399/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2594 - accuracy: 0.9034
# Epoch 400/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.9076
# Epoch 401/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2559 - accuracy: 0.9128
# Epoch 402/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2483 - accuracy: 0.9097
# Epoch 403/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2657 - accuracy: 0.9076
# Epoch 404/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9086
# Epoch 405/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.9086
# Epoch 406/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9160
# Epoch 407/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.9170
# Epoch 408/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2465 - accuracy: 0.9128
# Epoch 409/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9055
# Epoch 410/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2552 - accuracy: 0.9149
# Epoch 411/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9181
# Epoch 412/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2652 - accuracy: 0.9002
# Epoch 413/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.9149
# Epoch 414/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.9076
# Epoch 415/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9128
# Epoch 416/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9139
# Epoch 417/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9044
# Epoch 418/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.9107
# Epoch 419/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2566 - accuracy: 0.9191
# Epoch 420/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9139
# Epoch 421/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.9097
# Epoch 422/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2538 - accuracy: 0.9107
# Epoch 423/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.9097
# Epoch 424/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9086
# Epoch 425/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.9002
# Epoch 426/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2603 - accuracy: 0.9128
# Epoch 427/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2447 - accuracy: 0.9055
# Epoch 428/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.9044
# Epoch 429/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9118
# Epoch 430/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2472 - accuracy: 0.9076
# Epoch 431/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.9086
# Epoch 432/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2523 - accuracy: 0.9076
# Epoch 433/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.9076
# Epoch 434/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.9076
# Epoch 435/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.9107
# Epoch 436/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2572 - accuracy: 0.9097
# Epoch 437/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 0.9107
# Epoch 438/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2549 - accuracy: 0.9055
# Epoch 439/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.9097
# Epoch 440/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.9097
# Epoch 441/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.9055
# Epoch 442/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.9107
# Epoch 443/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.9097
# Epoch 444/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2514 - accuracy: 0.9128
# Epoch 445/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.9170
# Epoch 446/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9055
# Epoch 447/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9055
# Epoch 448/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9139
# Epoch 449/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2551 - accuracy: 0.9149
# Epoch 450/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.9202
# Epoch 451/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.9107: 0s - loss: 0.2632 - accuracy: 0.91
# Epoch 452/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9118
# Epoch 453/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9181
# Epoch 454/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9181
# Epoch 455/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9107
# Epoch 456/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.9013
# Epoch 457/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9076
# Epoch 458/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.9139
# Epoch 459/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2446 - accuracy: 0.9212
# Epoch 460/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2389 - accuracy: 0.9086
# Epoch 461/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2455 - accuracy: 0.9097
# Epoch 462/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2391 - accuracy: 0.9097
# Epoch 463/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.9107
# Epoch 464/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.9160
# Epoch 465/2000
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2510 - accuracy: 0.9118
# Epoch 466/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.9107
# Epoch 467/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2547 - accuracy: 0.9139
# Epoch 468/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2609 - accuracy: 0.9118
# Epoch 469/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9170
# Epoch 470/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2436 - accuracy: 0.9065
# Epoch 471/2000
# ...
# Epoch 1850/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9118
# Epoch 1851/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9023
# Epoch 1852/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2265 - accuracy: 0.9160
# Epoch 1853/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9128
# Epoch 1854/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9149
# Epoch 1855/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2212 - accuracy: 0.9139
# Epoch 1856/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2257 - accuracy: 0.9139
# Epoch 1857/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9149
# Epoch 1858/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.9202
# Epoch 1859/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9149
# Epoch 1860/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9107
# Epoch 1861/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9107
# Epoch 1862/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.9128
# Epoch 1863/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.9076
# Epoch 1864/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.9107
# Epoch 1865/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2203 - accuracy: 0.9223
# Epoch 1866/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2269 - accuracy: 0.9160
# Epoch 1867/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2190 - accuracy: 0.9233
# Epoch 1868/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9191
# Epoch 1869/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.9118
# Epoch 1870/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.9170
# Epoch 1871/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.9160
# Epoch 1872/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.9212
# Epoch 1873/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.9065
# Epoch 1874/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9181
# Epoch 1875/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9181
# Epoch 1876/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.9181
# Epoch 1877/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9149
# Epoch 1878/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9160
# Epoch 1879/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.9160
# Epoch 1880/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.9097
# Epoch 1881/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2068 - accuracy: 0.9244
# Epoch 1882/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.9160
# Epoch 1883/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2308 - accuracy: 0.9212
# Epoch 1884/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9170
# Epoch 1885/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.9149
# Epoch 1886/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.9160
# Epoch 1887/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9223
# Epoch 1888/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2268 - accuracy: 0.9160
# Epoch 1889/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9191
# Epoch 1890/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2391 - accuracy: 0.9170
# Epoch 1891/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9202
# Epoch 1892/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9191
# Epoch 1893/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.9128
# Epoch 1894/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2410 - accuracy: 0.9118
# Epoch 1895/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2183 - accuracy: 0.9233
# Epoch 1896/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2227 - accuracy: 0.9170
# Epoch 1897/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2144 - accuracy: 0.9233
# Epoch 1898/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.9170
# Epoch 1899/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9202
# Epoch 1900/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.9160
# Epoch 1901/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.9202
# Epoch 1902/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9160
# Epoch 1903/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2202 - accuracy: 0.9149
# Epoch 1904/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9170
# Epoch 1905/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2375 - accuracy: 0.9139
# Epoch 1906/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.9107
# Epoch 1907/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.9170
# Epoch 1908/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9286
# Epoch 1909/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9244
# Epoch 1910/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2379 - accuracy: 0.9170
# Epoch 1911/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2236 - accuracy: 0.9191
# Epoch 1912/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2180 - accuracy: 0.9202
# Epoch 1913/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.9191
# Epoch 1914/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9160
# Epoch 1915/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2430 - accuracy: 0.9118: 0s - loss: 0.2466 - accuracy: 0.91
# Epoch 1916/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2381 - accuracy: 0.9139
# Epoch 1917/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.9097
# Epoch 1918/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9107
# Epoch 1919/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2261 - accuracy: 0.9139
# Epoch 1920/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2223 - accuracy: 0.9181
# Epoch 1921/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9160
# Epoch 1922/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2170 - accuracy: 0.9181
# Epoch 1923/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.9118
# Epoch 1924/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.9149
# Epoch 1925/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2453 - accuracy: 0.9044
# Epoch 1926/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2249 - accuracy: 0.9181
# Epoch 1927/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9118
# Epoch 1928/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9160
# Epoch 1929/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9181
# Epoch 1930/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9139
# Epoch 1931/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9223
# Epoch 1932/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2180 - accuracy: 0.9191
# Epoch 1933/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9139
# Epoch 1934/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 0.9118
# Epoch 1935/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2212 - accuracy: 0.9202
# Epoch 1936/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2079 - accuracy: 0.9254
# Epoch 1937/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.9097
# Epoch 1938/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.9160
# Epoch 1939/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9202
# Epoch 1940/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2341 - accuracy: 0.9181
# Epoch 1941/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2279 - accuracy: 0.9139
# Epoch 1942/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.9149
# Epoch 1943/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2376 - accuracy: 0.9128
# Epoch 1944/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2158 - accuracy: 0.9181
# Epoch 1945/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9055
# Epoch 1946/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2360 - accuracy: 0.9160
# Epoch 1947/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2352 - accuracy: 0.9202
# Epoch 1948/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9128
# Epoch 1949/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.9128
# Epoch 1950/2000
# 30/30 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.91 - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9160
# Epoch 1951/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9160
# Epoch 1952/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9170
# Epoch 1953/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2248 - accuracy: 0.9254
# Epoch 1954/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2243 - accuracy: 0.9223
# Epoch 1955/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.9149
# Epoch 1956/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.9139
# Epoch 1957/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2363 - accuracy: 0.9086
# Epoch 1958/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9181
# Epoch 1959/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9160
# Epoch 1960/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.9149
# Epoch 1961/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9076
# Epoch 1962/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2199 - accuracy: 0.9160
# Epoch 1963/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2248 - accuracy: 0.9149
# Epoch 1964/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9212
# Epoch 1965/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2248 - accuracy: 0.9181
# Epoch 1966/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.9076
# Epoch 1967/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9212
# Epoch 1968/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9202
# Epoch 1969/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9170
# Epoch 1970/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9191
# Epoch 1971/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9202
# Epoch 1972/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.9149
# Epoch 1973/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2226 - accuracy: 0.9181: 0s - loss: 0.2232 - accuracy: 0.91
# Epoch 1974/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9128
# Epoch 1975/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9244
# Epoch 1976/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9149
# Epoch 1977/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9212
# Epoch 1978/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2267 - accuracy: 0.9097
# Epoch 1979/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2286 - accuracy: 0.9170
# Epoch 1980/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2152 - accuracy: 0.9202
# Epoch 1981/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9233
# Epoch 1982/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9181
# Epoch 1983/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2273 - accuracy: 0.9191
# Epoch 1984/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9202
# Epoch 1985/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2286 - accuracy: 0.9191
# Epoch 1986/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2195 - accuracy: 0.9212
# Epoch 1987/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9034
# Epoch 1988/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9118
# Epoch 1989/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2195 - accuracy: 0.9202
# Epoch 1990/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2152 - accuracy: 0.9160
# Epoch 1991/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9086
# Epoch 1992/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9065
# Epoch 1993/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2157 - accuracy: 0.9212
# Epoch 1994/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9128
# Epoch 1995/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2241 - accuracy: 0.9160
# Epoch 1996/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2326 - accuracy: 0.9118
# Epoch 1997/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2158 - accuracy: 0.9181
# Epoch 1998/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2226 - accuracy: 0.9118
# Epoch 1999/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2287 - accuracy: 0.9170
# Epoch 2000/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.9223
# Test score: 0.17513786256313324
# Test accuracy: 0.9453781247138977
# INFO:tensorflow:Assets written to: C:\Users\Jay\AppData\Local\Temp\tmp9czostre\assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
print(scaler.mean_)
print(scaler.scale_)
# Out:
# [67.15546218  2.63235294  0.30042017  0.1460084   0.55357143]
# [20.13277856  1.15651404  0.45844072  0.35311464  0.49712182]

# %%
interpreter = tf.lite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(input_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09da819195e6> in <module>
#       1 # 加载TFLite模型并分配张量（tensor）。
# ----> 2 interpreter = tf.lite.Interpreter(model_path="model.tflite")
#       3 interpreter.allocate_tensors()
#       4
#       5 # 获取输入和输出张量的信息。
#
# NameError: name 'tf' is not defined
